# %% [markdown]
# Problem Statement
#
# Analyze the dataset using Pandas to determine :
# 1. Total number of fire department fac in NYC
# 2. Number of fire department fac in each borough
# 3. Names of fac in Manhattan

# %%
import pandas as pd

# %%
df_fdny_raw = pd.read_csv(r"D:\Data Thoriq\Ngoding\Data Science Projects\datasets src\FDNY_Firehouse_Listing.csv")

# %%
df_fdny_raw.describe
# Out:
# <bound method NDFrame.describe of                                           FacilityName  \
# 0                                   Engine 4/Ladder 15
# 1                                             Engine 6
# 2    Manhattan Borough Command/Battalion 1/Engine 7...
# 3                                             Ladder 8
# 4                                    Engine 9/Ladder 6
# ..                                                 ...
# 214                               Engine 167/Ladder 87
# 215                               Engine 164/Ladder 84
# 216                               Engine 151/Ladder 76
# 217                                         Engine 168
# 218                                           Marine 9
#
#               FacilityAddress        Borough  Postcode   Latitude  Longitude  \
# 0             42 South Street      Manhattan     10005  40.703694 -74.007717
# 1           49 Beekman Street      Manhattan     10038  40.709971 -74.005395
# ...

# %%
df_fdny_raw.head()
# Out:
#                                         FacilityName     FacilityAddress  \
# 0                                 Engine 4/Ladder 15     42 South Street
# 1                                           Engine 6   49 Beekman Street
# 2  Manhattan Borough Command/Battalion 1/Engine 7...    100 Duane Street
# 3                                           Ladder 8  14 N. Moore Street
# 4                                  Engine 9/Ladder 6     75 Canal Street
#
#      Borough  Postcode   Latitude  Longitude  Community Board  \
# 0  Manhattan     10005  40.703694 -74.007717              101
# 1  Manhattan     10038  40.709971 -74.005395              101
# 2  Manhattan     10007  40.715339 -74.006300              101
# 3  Manhattan     10013  40.719574 -74.006620              101
# 4  Manhattan     10002  40.715408 -73.992834              103
#
#    Community Council   Census Tract      BIN         BBL  \
# 0                   1             7  1000867  1000350001
# ...

# %%
df_fdny_analyze = df_fdny_raw[['FacilityName', 'FacilityAddress', 'Borough']]
df_fdny_analyze.head()
# Out:
#                                         FacilityName     FacilityAddress  \
# 0                                 Engine 4/Ladder 15     42 South Street
# 1                                           Engine 6   49 Beekman Street
# 2  Manhattan Borough Command/Battalion 1/Engine 7...    100 Duane Street
# 3                                           Ladder 8  14 N. Moore Street
# 4                                  Engine 9/Ladder 6     75 Canal Street
#
#      Borough
# 0  Manhattan
# 1  Manhattan
# 2  Manhattan
# 3  Manhattan
# 4  Manhattan

# %%
df_fdny_analyze.describe()
# Out:
#                               FacilityName     FacilityAddress   Borough
# count                                  219                 219       219
# unique                                 219                 219         5
# top     Battalion 45/Engine 259/Ladder 128  14 N. Moore Street  Brooklyn
# freq                                     1                   1        66

# %%
df_fdny_analyze.columns
# Out:
# Index(['FacilityName', 'FacilityAddress', 'Borough'], dtype='object')

# %%
df_fdny_analyze.index
# Out:
# RangeIndex(start=0, stop=219, step=1)

# %% [markdown]
# 1. Total number of fire depart fac in NYC

# %%
df_fdny_analyze.count()
# Out:
# FacilityName       219
# FacilityAddress    219
# Borough            219
# dtype: int64

# %%
df_fdny_analyze.dtypes
# Out:
# FacilityName       object
# FacilityAddress    object
# Borough            object
# dtype: object

# %% [markdown]
# 2. Number of fire depart fac in each borough

# %%
gb_borough = df_fdny_analyze.groupby('Borough')
gb_borough.size()
# Out:
# Borough
# Bronx            34
# Brooklyn         66
# Manhattan        48
# Queens           51
# Staten Island    20
# dtype: int64

# %% [markdown]
# 3. Names fac in Manhattan

# %%
fdny_info_manhattan = gb_borough.get_group('Manhattan')
fdny_info_manhattan
# Out:
#                                          FacilityName  \
# 0                                  Engine 4/Ladder 15
# 1                                            Engine 6
# 2   Manhattan Borough Command/Battalion 1/Engine 7...
# 3                                            Ladder 8
# 4                                   Engine 9/Ladder 6
# 5                     Battalion 4/Engine 15/Ladder 18
# 6                                 Engine 28/Ladder 11
# 7                                            Engine 5
# 8                                Division 1/Ladder 20
# 9                                  Engine 33/Ladder 9
# 10                               Battalion 6/Ladder 3
# 11                                           Squad 18
# 12                                Engine 34/Ladder 21
# 13                                          Engine 26
# 14                     Battalion 7/Engine 3/Ladder 12
# 15                                 Engine 1/Ladder 24
# ...
