# %% [markdown]
# Problem Statement
#
# Using the two data points cause of death and percentile, draw a pie chart to visualize the dataset.

# %%
from matplotlib import style
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd

# %%
ohio_death = {
    'Cause' : ['Chronic Diseases', 'Unintentional Injuries', 'Alzheimers', 'Infuenza and Pneumonia', 'Sepsis', 'Others'],
    'Percentile' : [62,10,5,8,2,6]
}

df_ohio_death = pd.DataFrame(ohio_death)
df_ohio_death
# Out:
#                     Cause  Percentile
# 0        Chronic Diseases          62
# 1  Unintentional Injuries          10
# 2              Alzheimers           5
# 3  Infuenza and Pneumonia           8
# 4                  Sepsis           2
# 5                  Others           6

# %%
plt.figure(figsize=(10,10))
plt.pie(percentile, labels=cause, autopct='%1.1f%%', startangle=30, textprops=dict(color="w"))
plt.axis('equal')
plt.title('Ohio State - 2012 : Leading causes of death')
# Out:
# Text(0.5, 1.0, 'Ohio State - 2012 : Leading causes of death')
